# %%
import pandas as pd

# %%
df = pd.read_csv("Streamlit/data/df_reseñas_wordcloud.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pd.read_csv("Streamlit/data/df_reseñas_wordcloud.csv")
#
# File /opt/anaconda3/envs/original/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#       Unnamed: 0                     Title  \
# 0              8                Squid Game
# 1              8                Squid Game
# 2              8                Squid Game
# 3              8                Squid Game
# 4              8                Squid Game
# ...          ...                       ...
# 1397        9581     The Last Man On Earth
# 1398        9582  So I Married An Anti-Fan
# 1399        9582  So I Married An Anti-Fan
# 1400        9583                  Porridge
# 1401        9605             Party Of Five
#
#                                                  Poster  \
# 0     https://image.tmdb.org/t/p/w500/1QdXdRYfktUSON...
# 1     https://image.tmdb.org/t/p/w500/1QdXdRYfktUSON...
# 2     https://image.tmdb.org/t/p/w500/1QdXdRYfktUSON...
# 3     https://image.tmdb.org/t/p/w500/1QdXdRYfktUSON...
# 4     https://image.tmdb.org/t/p/w500/1QdXdRYfktUSON...
# ...                                                 ...
# ...
