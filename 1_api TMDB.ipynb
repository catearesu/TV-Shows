# %%
import requests
import pandas as pd
import numpy as np
import time
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
clave_api= os.getenv("clave_api")

# %%
url = "https://api.themoviedb.org/3/discover/tv"
params ={"api_key": clave_api}
# Base URL para las imágenes
BASE_IMG_URL = "https://image.tmdb.org/t/p/w500"

# %%
url_generos = 'https://api.themoviedb.org/3/genre/tv/list'
try:
        # Hacer la solicitud a la API para obtener los géneros 
        genero_response = requests.get(url_generos, params=params) 
        genero_response.raise_for_status()  # Asegura que no haya error en la solicitud

        if genero_response.status_code == 200:
            generos = genero_response.json()['genres']
            # me quedo con el nombre del genero y el id para luego hacer match con la response en la que tengo solo el ID del genero
            generos_dict = {genero["id"]:genero['name'] for genero in generos} # // value de genero_id : value de genero_name
        else:
            print(f"Error {genero_response.status_code}: No se pudo obtener el genero")

except requests.exceptions.RequestException as e:
        print(f"Error al obtener géneros: {e}")

# %%
generos_dict
# Out:
# {10759: 'Action & Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  10762: 'Kids',
#  9648: 'Mystery',
#  10763: 'News',
#  10764: 'Reality',
#  10765: 'Sci-Fi & Fantasy',
#  10766: 'Soap',
#  10767: 'Talk',
#  10768: 'War & Politics',
#  37: 'Western'}

# %%
# Función principal para obtener información de todas las series
def get_all_series(pages):
    todas_series = []
    processed_ids = set()  # Set para almacenar los IDs ya procesados
    url_generos = 'https://api.themoviedb.org/3/genre/tv/list'
    params ={"api_key": clave_api}
    
    try:
        # Hacer la solicitud a la API para obtener los GENEROS
        genero_response = requests.get(url_generos, params=params) 
        genero_response.raise_for_status()  # Asegura que no haya error en la solicitud

        if genero_response.status_code == 200:
            generos = genero_response.json()['genres']
            # me quedo con el nombre del genero y el id para luego hacer match con la response en la que tengo solo el ID del genero
            generos_dict = {genero["id"]:genero['name'] for genero in generos} # // value de genero_id : value de genero_name
        else:
            print(f"Error {genero_response.status_code}: No se pudo obtener el genero")

    except requests.exceptions.RequestException as e:
        print(f"Error al obtener géneros: {e}")

    for page in range(1, pages + 1):
        url = "https://api.themoviedb.org/3/tv/popular"
        #url = "https://api.themoviedb.org/3/discover/tv"
        try:
            response = requests.get(url, params={**params, "page":page})
            response.raise_for_status()  # Asegura que no haya error en la solicitud
            # Verificamos cuántas peticiones quedan en el límite
            remaining_requests = int(response.headers.get("X-RateLimit-Remaining", 0))
            if remaining_requests == 0:
                print("Límite de peticiones alcanzado. Esperando...")
                time.sleep(10)  # Espera de 60 segundos si el límite es 0
        
            if response.status_code == 200:
                info_series = response.json()["results"]       
                
                for serie in info_series:
                    series_id = serie.get('id')  # ID de la serie
                    # Si ya procesamos esta serie, saltamos a la siguiente
                    if series_id in processed_ids:
                        continue
                    # Marcar el ID como procesado
                    processed_ids.add(series_id)

                    # Obtener información básica de la serie
                    title = serie.get("name")
                    synopsis = serie.get("overview")
                    rating = serie.get("vote_average")
                    first_air_date = serie.get("first_air_date")
                    last_air_date = serie.get("last_air_date")
                    genero_ids = serie.get("genre_ids") # me devuelve una lista de IDS de genero
                    popularity = serie.get("popularity")
                    original_language = serie.get("original_language")
                    origin_country = ", ".join([str(country) for country in serie.get("origin_country",[])if country]) if serie.get("origin_country") else "No data available"
                    number_ratings = serie.get("vote_count")
                    genero = ', '.join([generos_dict.get(genero_id, "Desconocido") for genero_id in genero_ids])
                    # Para cada genre_id, busco el nombre del género en el diccionario generos_dict
                    # La función get en los diccionarios me devuelve el valor asociado a una clave, 
                    # en este caso, el nombre del género correspondiente al genre_id.

                    # Quiero obtener la duración promedio de los episodios, el número de temporadas, el número de episodios y la plataforma
                    duracion_episodio = 0  # lo ponemos a 0
                    number_of_seasons = 0 # el número de temporadas también lo ponemos a 0
                    number_of_episodes = 0
                    production_companies = []
                    where_to_watch = []
                    reviews = []
                    presupuesto = 0
                    recaudacion = 0
                    cast = []
                    created_by = []
                    tagline =[]
                    in_production = []
                    status = []
                    vote_average = 0
                    poster_path = None
                    trailer = None

                    # solicitamos a la API detalles ADICIONALES (número de temporadas, número de episodios y duración)
                    url_series_id = f"https://api.themoviedb.org/3/tv/{series_id}"
                    details_response = requests.get(url_series_id, params=params)
                    if details_response.status_code == 200:
                            details = details_response.json()
                            # número de temporadas
                            number_of_seasons = details.get("number_of_seasons") 
                            # número de episodios
                            number_of_episodes = details.get("number_of_episodes")
                            # Duración de los episodios en minutos (si está disponible)
                            duracion_episodio = details.get("episode_run_time") 
                            if duracion_episodio:
                                duracion_episodio = sum(duracion_episodio) / len(duracion_episodio)  # Promedio de las duraciones
                            else:
                                duracion_episodio = 0  # Si no hay datos de duración ponemos 0  
                            # Extraer tagline, status y creadores
                            tagline = details.get("tagline", "No disponible")
                            in_production = details.get("in_production", "No disponible")
                            status = details.get("status", "No disponible")
                            created_by = [creator["name"] for creator in details.get("created_by")]
                            created_by = ", ".join(set(created_by))
                            vote_average = details.get("vote_average", "No disponible")
                            # Extraer las compañías productoras
                            production_companies = [company["name"] for company in details.get("production_companies")]
                            production_companies = ", ".join(set(production_companies))
                            # sacamos budget y recaudación
                            presupuesto = details.get("budget", "No data available")
                            recaudacion = details.get("revenue", "No data available")
                            poster_path = f"{BASE_IMG_URL}{details.get("poster_path")}"
    
                    
                    # solicitamos a la API la info de PLATAFORMAS donde ver las series
                    where_to_watch_url = f"https://api.themoviedb.org/3/tv/{series_id}/watch/providers"
                    donde_ver_response = requests.get(where_to_watch_url, params = params)
                    if donde_ver_response.status_code == 404:
                    # Asignamos valores predeterminados si la serie no se encuentra
                        where_to_watch = ["No disponible"]
                    elif donde_ver_response.status_code == 200:
                        donde_ver_info = donde_ver_response.json()["results"]
                        # sacamos las plataformas
                        for country, plataforma_info in donde_ver_info.items():
                            if "flatrate" in plataforma_info:
                                for plataforma in plataforma_info["flatrate"]:
                                        where_to_watch.append(plataforma["provider_name"])
                        # una vez añadidas todas las plataformas, elimininamos duplicados y quitamos la lista
                        where_to_watch = ", ".join(set(where_to_watch)) if where_to_watch else "No platforms available"
                    
                    # Solicitamos a la API las RESEÑAS de la serie
                    reviews_url = f"https://api.themoviedb.org/3/tv/{series_id}/reviews"
                    reviews_response = requests.get(reviews_url, params=params)
                    if reviews_response.status_code == 200:
                        reviews_data = reviews_response.json()
                        # Extraemos las reseñas
                        
                        for review in reviews_data["results"]:
                            review_content = review.get("content", "No review available")
                            reviews.append(review_content)
                    
                        # Si hay reseñas las unimos 
                        reviews_text = " | ".join(reviews) if reviews else "No reviews"
                    # reviews=[] 
                    # reviews=["muy bien", "perfecto"]
                    else:
                        reviews_text = "No reviews available"  # Si no hay reseñas, asignamos un texto predeterminado

                    # Solicitamos a la API los CREDITOS (actores principales y directores)
                    credits_url = f"https://api.themoviedb.org/3/tv/{series_id}/credits"
                    credits_response = requests.get(credits_url, params=params)
                    if credits_response.status_code == 200:
                        credits = credits_response.json()
                        # Obtener los primeros actores principales
                        cast = [actor["name"] for actor in credits.get("cast")[:5]]  # Primeros 5 actores
                    

                    # Solicitamos a la API los TRAILERS
                    videos_url = f"https://api.themoviedb.org/3/tv/{series_id}/videos"
                    videos_response = requests.get(videos_url, params=params)
                    if videos_response.status_code == 200:
                        videos = videos_response.json()["results"]
                        trailer_url = next((video for video in videos if video["type"] == "Trailer"), None)
                        if trailer_url:
                            trailer = f"https://www.youtube.com/watch?v={trailer_url['key']}"
                        else:
                            trailer = "No trailer available"

                    # Añadimos la serie al DataFrame
                    todas_series.append({
                        "Title": title,
                        "Synopsis": synopsis,
                        "Tagline": tagline,
                        "Genero": genero,
                        "Rating": rating,
                        "Popularity": popularity,
                        "Vote Count": number_ratings,
                        "Vote Average": vote_average,
                        "Original Language": original_language,
                        "Origin Country": origin_country,
                        "First Air Date": first_air_date,
                        "Last Air Date": last_air_date,
                        "In production": in_production,
                        "Status": status,
                        "Number of Season": number_of_seasons,
                        "Number of Episodes": number_of_episodes,
                        "Episode Duration": duracion_episodio,
                        "Production Companies": production_companies,
                        "Where to Watch": where_to_watch,
                        "Reviews": reviews_text,
                        "Budget": presupuesto,
                        "Revenue": recaudacion,
                        "Cast": ", ".join(cast),  # Unimos los nombres de los actores principales
                        "Creators": created_by,
                        "Poster": poster_path,
                        "Trailer": trailer
                    })
            else:
                print(f"Error {response.status_code}: No se pudo obtener los datos de la página {page}")
            print(f"Obteniendo datos de la página {page}... total de: {len(todas_series)} series")
        except requests.exceptions.RequestException as e:
            print(f"Error al obtener series de la página {page}: {e}")
            continue  # Continuar con la siguiente página si ha habido un error
    df = pd.DataFrame(todas_series)
    return df

# %%
# Llamar a la función
df = get_all_series(500)  # Número de páginas que quiero obtener
# Out:
# Obteniendo datos de la página 1... total de: 20 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 2... total de: 40 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 3... total de: 55 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 4... total de: 74 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 5... total de: 90 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 6... total de: 104 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 7... total de: 121 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 8... total de: 137 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 9... total de: 155 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 10... total de: 170 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 11... total de: 188 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 12... total de: 198 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 13... total de: 217 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 14... total de: 236 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 14: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/8425?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 15... total de: 237 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 16... total de: 251 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 17... total de: 268 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 18... total de: 288 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 19... total de: 306 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 20... total de: 322 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 21... total de: 341 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 22... total de: 354 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 23... total de: 371 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 23: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/494/watch/providers?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 24... total de: 374 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 24: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/91444/reviews?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 25... total de: 376 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 25: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/34524?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 26... total de: 393 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 27... total de: 411 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 28... total de: 426 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 29... total de: 440 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 30... total de: 455 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 31... total de: 470 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 32... total de: 488 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 33... total de: 507 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 34... total de: 519 series
# Error al obtener series de la página 34: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=34 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 35... total de: 519 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 35: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/128015?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 36... total de: 519 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 37... total de: 539 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 38... total de: 556 series
# Límite de peticiones alcanzado. Esperando...
# Error al obtener series de la página 38: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/210078?api_key=ec22ff4324626e29da4fb46a76ce6a7d (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página
series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 279... total de: 4344 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 280... total de: 4363 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 281... total de: 4381 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 282... total de: 4400 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 283... total de: 4419 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 284... total de: 4438 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 285... total de: 4458 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 286... total de: 4475 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 287... total de: 4495 series
# Límite de peticiones alcanzado. Esperando...
# Obteniendo datos de la página 288... total de: 4514 series
# Límite de peticiones alcanzado. Esperando...
# ...
# Obteniendo datos de la página 9486... total de: 8245 series
# Error al obtener series de la página 9486: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9486
# Obteniendo datos de la página 9487... total de: 8245 series
# Error al obtener series de la página 9487: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9487
# Obteniendo datos de la página 9488... total de: 8245 series
# Error al obtener series de la página 9488: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9488
# Obteniendo datos de la página 9489... total de: 8245 series
# Error al obtener series de la página 9489: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9489
# Obteniendo datos de la página 9490... total de: 8245 series
# Error al obtener series de la página 9490: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9490
# Obteniendo datos de la página 9491... total de: 8245 series
# Error al obtener series de la página 9491: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9491
# Obteniendo datos de la página 9492... total de: 8245 series
# Error al obtener series de la página 9492: HTTPSConnectionPool(host='api.themoviedb.org', port=443): Max retries exceeded with url: /3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9492 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Obteniendo datos de la página 9493... total de: 8245 series
# Error al obtener series de la página 9493: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9493
# Obteniendo datos de la página 9494... total de: 8245 series
# Error al obtener series de la página 9494: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9494
# Obteniendo datos de la página 9495... total de: 8245 series
# Error al obtener series de la página 9495: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9495
# Obteniendo datos de la página 9496... total de: 8245 series
# Error al obtener series de la página 9496: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9496
# Obteniendo datos de la página 9497... total de: 8245 series
# Error al obtener series de la página 9497: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9497
# Obteniendo datos de la página 9498... total de: 8245 series
# Error al obtener series de la página 9498: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9498
# Obteniendo datos de la página 9499... total de: 8245 series
# Error al obtener series de la página 9499: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9499
# Obteniendo datos de la página 9500... total de: 8245 series
# Error al obtener series de la página 9500: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9500
# Obteniendo datos de la página 9501... total de: 8245 series
# Error al obtener series de la página 9501: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9501
# Obteniendo datos de la página 9502... total de: 8245 series
# Error al obtener series de la página 9502: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9502
# Obteniendo datos de la página 9503... total de: 8245 series
# Error al obtener series de la página 9503: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9503
# Obteniendo datos de la página 9504... total de: 8245 series
# Error al obtener series de la página 9504: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9504
# Obteniendo datos de la página 9505... total de: 8245 series
# Error al obtener series de la página 9505: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9505
# Obteniendo datos de la página 9506... total de: 8245 series
# Error al obtener series de la página 9506: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9506
# Obteniendo datos de la página 9507... total de: 8245 series
# Error al obtener series de la página 9507: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9507
# Obteniendo datos de la página 9508... total de: 8245 series
# Error al obtener series de la página 9508: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9508
# Obteniendo datos de la página 9509... total de: 8245 series
# Error al obtener series de la página 9509: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9509
# Obteniendo datos de la página 9510... total de: 8245 series
# Error al obtener series de la página 9510: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9510
# Obteniendo datos de la página 9511... total de: 8245 series
# Error al obtener series de la página 9511: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9511
# Obteniendo datos de la página 9512... total de: 8245 series
# Error al obtener series de la página 9512: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9512
# Obteniendo datos de la página 9513... total de: 8245 series
# Error al obtener series de la página 9513: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9513
# Obteniendo datos de la página 9514... total de: 8245 series
# Error al obtener series de la página 9514: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9514
# Obteniendo datos de la página 9515... total de: 8245 series
# Error al obtener series de la página 9515: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9515
# Obteniendo datos de la página 9516... total de: 8245 series
# Error al obtener series de la página 9516: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9516
# Obteniendo datos de la página 9517... total de: 8245 series
# Error al obtener series de la página 9517: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9517
# Obteniendo datos de la página 9518... total de: 8245 series
# Error al obtener series de la página 9518: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9518
# Obteniendo datos de la página 9519... total de: 8245 series
# Error al obtener series de la página 9519: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9519
# Obteniendo datos de la página 9520... total de: 8245 series
# Error al obtener series de la página 9520: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9520
# Obteniendo datos de la página 9521... total de: 8245 series
# Error al obtener series de la página 9521: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9521
# Obteniendo datos de la página 9522... total de: 8245 series
# Error al obtener series de la página 9522: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9522
# Obteniendo datos de la página 9523... total de: 8245 series
# Error al obtener series de la página 9523: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9523
# Obteniendo datos de la página 9524... total de: 8245 series
# Error al obtener series de la página 9524: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9524
# Obteniendo datos de la página 9525... total de: 8245 series
# Error al obtener series de la página 9525: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9525
# Obteniendo datos de la página 9526... total de: 8245 series
# Error al obtener series de la página 9526: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9526
# Obteniendo datos de la página 9527... total de: 8245 series
# Error al obtener series de la página 9527: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9527
# Obteniendo datos de la página 9528... total de: 8245 series
# Error al obtener series de la página 9528: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9528
# Obteniendo datos de la página 9529... total de: 8245 series
# Error al obtener series de la página 9529: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9529
# Obteniendo datos de la página 9530... total de: 8245 series
# Error al obtener series de la página 9530: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9530
# Obteniendo datos de la página 9531... total de: 8245 series
# Error al obtener series de la página 9531: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9531
# Obteniendo datos de la página 9532... total de: 8245 series
# Error al obtener series de la página 9532: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9532
# Obteniendo datos de la página 9533... total de: 8245 series
# Error al obtener series de la página 9533: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9533
# Obteniendo datos de la página 9534... total de: 8245 series
# Error al obtener series de la página 9534: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9534
# Obteniendo datos de la página 9535... total de: 8245 series
# Error al obtener series de la página 9535: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9535
# Obteniendo datos de la página 9536... total de: 8245 series
# Error al obtener series de la página 9536: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9536
# Obteniendo datos de la página 9537... total de: 8245 series
# Error al obtener series de la página 9537: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9537
# Obteniendo datos de la página 9538... total de: 8245 series
# Error al obtener series de la página 9538: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9538
# Obteniendo datos de la página 9539... total de: 8245 series
# Error al obtener series de la página 9539: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9539
# Obteniendo datos de la página 9540... total de: 8245 series
# Error al obtener series de la página 9540: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9540
# Obteniendo datos de la página 9541... total de: 8245 series
# Error al obtener series de la página 9541: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9541
# Obteniendo datos de la página 9542... total de: 8245 series
# Error al obtener series de la página 9542: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9542
# Obteniendo datos de la página 9543... total de: 8245 series
# Error al obtener series de la página 9543: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9543
# Obteniendo datos de la página 9544... total de: 8245 series
# Error al obtener series de la página 9544: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9544
# Obteniendo datos de la página 9545... total de: 8245 series
# Error al obtener series de la página 9545: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9545
# Obteniendo datos de la página 9546... total de: 8245 series
# Error al obtener series de la página 9546: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9546
# Obteniendo datos de la página 9547... total de: 8245 series
# Error al obtener series de la página 9547: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9547
# Obteniendo datos de la página 9548... total de: 8245 series
# Error al obtener series de la página 9548: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9548
# Obteniendo datos de la página 9549... total de: 8245 series
# Error al obtener series de la página 9549: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9549
# Obteniendo datos de la página 9550... total de: 8245 series
# Error al obtener series de la página 9550: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9550
# Obteniendo datos de la página 9551... total de: 8245 series
# Error al obtener series de la página 9551: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9551
# Obteniendo datos de la página 9552... total de: 8245 series
# Error al obtener series de la página 9552: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9552
# Obteniendo datos de la página 9553... total de: 8245 series
# Error al obtener series de la página 9553: 400 Client Error: Bad Request for url: https://api.themoviedb.org/3/tv/popular?api_key=ec22ff4324626e29da4fb46a76ce6a7d&page=9553

# %%
df.to_csv("series9700.csv")
